# %%
{
 "cells": [
    {
     "cell_type": "code",
     "execution_count": null,
     "metadata": {},
     "outputs": [],
     "source": []
    },
    {
     "cell_type": "markdown",
     "metadata": {},
     "source": [
        "# 🎯 e-Rehabilitation Assistant - Complete Demo\n",
        "## MTech AI/ML Project - All components in one notebook [memory:45]"
     ]
    },
    {
     "cell_type": "code",
     "execution_count": null,
     "metadata": {},
     "outputs": [],
     "source": [
        "# Install & Import\n",
        "!pip install -q streamlit langchain chromadb sentence-transformers transformers peft shap\n",
        "from src.nano_llm import NanoLLM\n",
        "from src.personalization import PatientDataManager"
     ]
    },
    {
     "cell_type": "code",
     "execution_count": null,
     "metadata": {},
     "outputs": [],
     "source": [
        "# Initialize full pipeline\n",
        "llm = NanoLLM()\n",
        "mgr = PatientDataManager()\n",
        "\n",
        "# Test patient query\n",
        "query = \"I feel sad today and my knee hurts when I walk.\"\n",
        "response = llm.generate_response(query, \"P001\")\n",
        "print(\"🤖 Response:\", response)"
     ]
    }
 ],
 "metadata": {
    "kernelspec": {
     "display_name": "Python 3",
     "language": "python",
     "name": "python3"
    }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
